# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Time-Wasters on Social Media.csv')
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %%
df["Watch Time"] = pd.to_datetime(df["Watch Time"], format="%I:%M %p")
df["Watch Hour"] = df["Watch Time"].dt.hour

# %%
df["Watch Time"] = pd.to_datetime(df["Watch Time"], format="%I:%M %p")
df["Watch Hour"] = df["Watch Time"].dt.hour

# %%
df["KiyasEgilimi"] = df["Watch Reason"].apply(lambda x: 1 if x in ["Procrastination", "Boredom"] else 0)

# %%
print(df.head())
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...     Watch Reason  DeviceType  \
# 0       Engineer        Rural  Instagram  ...  Procrastination  Smartphone
# 1         Artist        Urban  Instagram  ...            Habit    Computer
# 2       Engineer        Rural   Facebook  ...    Entertainment      Tablet
# 3  Waiting staff        Rural    YouTube  ...            Habit  Smartphone
# 4        Manager        Urban     TikTok  ...          Boredom  Smartphone
#
#         OS          Watch Time  Self Control  Addiction Level  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Time-Wasters on Social Media.csv')
def plot_distribution(data, column, kind="hist", bins=10, rotation=0):
    plt.figure(figsize=(8, 5))
    if kind == "hist":
        sns.histplot(data[column].dropna(), bins=bins, kde=True, color="skyblue")
    elif kind == "count":
        sns.countplot(x=column, data=data, palette="Set2")
        plt.xticks(rotation=rotation)
    plt.title(f"{column} Distribution")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()
plot_distribution(df, "Age", kind="hist", bins=15)

# %%
plot_distribution(df, "Gender", kind="count")
# Out:
# <ipython-input-9-3f833a21b3dd>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, palette="Set2")

# %%
plot_distribution(df, "Income", kind="hist", bins=20)

# %%
plot_distribution(df, "Location", kind="count", rotation=45)
# Out:
# <ipython-input-9-3f833a21b3dd>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, palette="Set2")

# %%
plot_distribution(df, "Profession", kind="count", rotation=90)
# Out:
# <ipython-input-9-3f833a21b3dd>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, palette="Set2")

# %%
plot_distribution(df, "Platform", kind="count", rotation=45)
# Out:
# <ipython-input-9-3f833a21b3dd>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, palette="Set2")

# %%
psychological_cols = ["Addiction Level", "Self Control", "Satisfaction", "ProductivityLoss"]

# Her bir gösterge için ayrı grafik çiz
for col in psychological_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col].dropna(), bins=15, kde=True, color="mediumpurple")
    plt.title(f"{col} Distribution")
    plt.xlabel(col)
    plt.ylabel("Kullanıcı Sayısı")
    plt.tight_layout()
    plt.show()

# %%
# K-Means Clustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

features = ["Addiction Level", "Self Control", "Satisfaction", "ProductivityLoss"]

df_kmeans = df[features].dropna()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_kmeans)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

df_kmeans["Cluster"] = clusters

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=clusters, palette="Set1")
plt.title("Kullanıcıların Psikolojik Özelliklerine Göre Kümeleme (K-Means)")
plt.xlabel("Bağımlılık (scaled)")
plt.ylabel("Özdenetim (scaled)")
plt.tight_layout()
plt.show()

df_kmeans.groupby("Cluster")[features].mean().round(2)
# Out:
#          Addiction Level  Self Control  Satisfaction  ProductivityLoss
# Cluster
# 0                   5.31          4.69          7.31              2.69
# 1                   0.26          9.74          2.10              7.90
# 2                   2.39          7.61          4.38              5.62

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Regresyon için kullanılacak sütunlar
regression_features = ["Addiction Level", "Self Control", "ProductivityLoss", "KiyasEgilimi"]
target = "Satisfaction"

df_reg = df[regression_features + [target]].dropna()

X = df_reg[regression_features]
y = df_reg[target]

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_.round(3)
})

coefficients["Intercept"] = model.intercept_.round(3)
coefficients, mse, r2
# Out:
# (            Feature  Coefficient  Intercept
#  0   Addiction Level          0.0       10.0
#  1      Self Control         -0.0       10.0
#  2  ProductivityLoss         -1.0       10.0
#  3      KiyasEgilimi          0.0       10.0,
#  1.4118243620740447e-29,
#  1.0)

# %%
# Psikolojik ve davranışsal değişkenler arasında korelasyon ısı haritası çizelim
corr_cols = [
    "Addiction Level", "Self Control", "Satisfaction",
    "ProductivityLoss", "KiyasEgilimi", "Total Time Spent",
    "Engagement", "Importance Score", "Scroll Rate"
]

# Geçerli sütunları filtrele (bazıları veri setinde olmayabilir)
corr_cols_valid = [col for col in corr_cols if col in df.columns]

# Korelasyon matrisi
corr_matrix = df[corr_cols_valid].corr()

# Görselleştirme
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Değişkenler Arası Korelasyon Isı Haritası")
plt.tight_layout()
plt.show()

# %%
# Ruhsal modu düşük olan bireyleri filtrele: Satisfaction ≤ 3
low_mood_users = df[df["Satisfaction"] <= 3]

low_mood_categories = low_mood_users["Video Category"].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=low_mood_categories.values, y=low_mood_categories.index, palette="Reds")
plt.title("Ruh Hali Düşük Bireylerin Tercih Ettiği Video Kategorileri")
plt.xlabel("Kullanıcı Sayısı")
plt.ylabel("Video Kategorisi")
plt.tight_layout()
plt.show()


low_mood_categories.head(5)
# Out:
# <ipython-input-21-7f9dd98fc108>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=low_mood_categories.values, y=low_mood_categories.index, palette="Reds")
# Video Category
# Jokes/Memes    55
# Pranks         39
# Life Hacks     36
# Vlogs          28
# Gaming         24
# Name: count, dtype: int64

# %%
# Cinsiyet bazlı tatmin ortalamalarını karşılaştıralım
gender_satisfaction = df.groupby("Gender")["Satisfaction"].mean().round(2)


plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Gender", y="Satisfaction", palette="pastel")
plt.title("Cinsiyete Göre Tatmin (Ruh Hali) Düzeyi Dağılımı")
plt.xlabel("Cinsiyet")
plt.ylabel("Tatmin Skoru")
plt.tight_layout()
plt.show()

male_satisfaction = df[df["Gender"] == "Male"]["Satisfaction"].dropna()
female_satisfaction = df[df["Gender"] == "Female"]["Satisfaction"].dropna()

from scipy.stats import ttest_ind
stat, p_val = ttest_ind(male_satisfaction, female_satisfaction, equal_var=False)

gender_satisfaction, p_val
# Out:
# <ipython-input-18-3422b4d99a06>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Gender", y="Satisfaction", palette="pastel")
# (Gender
#  Female    4.86
#  Male      4.92
#  Other     4.70
#  Name: Satisfaction, dtype: float64,
#  np.float64(0.672552542120487))

# %%
# Zaman kaybı hissi için "ProductivityLoss" skorunu baz alalım

time_vs_loss = df[["Total Time Spent", "ProductivityLoss"]].dropna()

from scipy.stats import pearsonr
corr, p_value = pearsonr(time_vs_loss["Total Time Spent"], time_vs_loss["ProductivityLoss"])

plt.figure(figsize=(8, 6))
sns.regplot(data=time_vs_loss, x="Total Time Spent", y="ProductivityLoss", scatter_kws={'alpha': 0.4})
plt.title("Sosyal Medyada Geçirilen Süre ile Zaman Kaybı Hissi Arasındaki İlişki")
plt.xlabel("Toplam Süre (dk)")
plt.ylabel("Zaman Kaybı Hissi (ProductivityLoss)")
plt.tight_layout()
plt.show()

corr, p_value
# Out:
# (np.float64(-0.014209752535846245), np.float64(0.653566938142635))

# %%
# "Procrastination" ve "Boredom" nedenlerini kıyas eğilimi olarak kodlayalım
df["KiyasEgilimi"] = df["Watch Reason"].apply(lambda x: 1 if x in ["Procrastination", "Boredom"] else 0)

plt.figure(figsize=(8, 6))
sns.boxplot(x="KiyasEgilimi", y="Satisfaction", data=df, palette="Set3")
plt.title("Kıyas Eğiliminin Tatmin Üzerindeki Etkisi")
plt.xlabel("Kıyas Eğilimi (0=Yok, 1=Var)")
plt.ylabel("Tatmin Skoru")
plt.tight_layout()
plt.show()

from sklearn.linear_model import LinearRegression

df_reg = df[["KiyasEgilimi", "Satisfaction"]].dropna()

X = df_reg[["KiyasEgilimi"]]
y = df_reg["Satisfaction"]

model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

coef = model.coef_[0]
intercept = model.intercept_
r2 = model.score(X, y)

coef, intercept, r2
# Out:
# <ipython-input-20-6e45e67e3487>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="KiyasEgilimi", y="Satisfaction", data=df, palette="Set3")
# (np.float64(-0.14623774494446284),
#  np.float64(4.922056384742952),
#  0.0011377900708644528)

# %%
from scipy.stats import pearsonr, spearmanr

control_vs_addiction = df[["Self Control", "Addiction Level"]].dropna()

pearson_corr, pearson_p = pearsonr(control_vs_addiction["Self Control"], control_vs_addiction["Addiction Level"])

spearman_corr, spearman_p = spearmanr(control_vs_addiction["Self Control"], control_vs_addiction["Addiction Level"])

plt.figure(figsize=(8, 6))
sns.regplot(data=control_vs_addiction, x="Self Control", y="Addiction Level", scatter_kws={'alpha':0.5})
plt.title("Özdenetim ile Sosyal Medya Bağımlılığı İlişkisi")
plt.xlabel("Özdenetim (Self Control)")
plt.ylabel("Bağımlılık (Addiction Level)")
plt.tight_layout()
plt.show()

pearson_corr, pearson_p, spearman_corr, spearman_p
# Out:
# (np.float64(-1.0), np.float64(0.0), np.float64(-1.0), np.float64(0.0))

# %%
# "Bağımlı kullanıcılar" olarak Addiction Level >= 6 kabul edelim
dependent_users = df[df["Addiction Level"] >= 6]

category_counts = dependent_users["Video Category"].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.values, y=category_counts.index, palette="Set2")
plt.title("Bağımlı Kullanıcıların Tercih Ettiği İçerik Türleri")
plt.xlabel("Kullanıcı Sayısı")
plt.ylabel("İçerik Türü (Kategori)")
plt.tight_layout()
plt.show()

category_counts.head()
# Out:
# <ipython-input-30-d44aaa8adfad>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.values, y=category_counts.index, palette="Set2")
# Video Category
# Life Hacks     17
# Jokes/Memes    15
# Vlogs          12
# Trends         10
# Gaming         10
# Name: count, dtype: int64
